# %%
import pandas as pd
df= pd.read_csv("/home/yasmeen/Computer_Vision_program/IMBD.csv")

print(df.head())
# Out:
#                                            movie  \
# 0                                    The Witcher
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                               Sound of Freedom
# 3                                Secret Invasion
# 4                           Special Ops: Lioness
#
#                                      genre  runtime certificate  rating  \
# 0     Action, Adventure, Drama               60 min           A     8.1
# 1  Action, Adventure, Thriller              163 min          UA     8.0
# 2     Action, Biography, Drama              131 min       PG-13     7.9
# 3     Action, Adventure, Drama               47 min      UA 16+     6.2
# 4      Action, Drama, Thriller                  NaN         NaN     7.5
#
#                                                stars  \
# 0  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 1  ['Tom Cruise, ', 'Hayley Atwell, ', 'Ving Rham...
# 2  ['Jim Caviezel, ', 'Mira Sorvino, ', 'Bill Cam...
# 3  ['Samuel L. Jackson, ', 'Emilia Clarke, ', 'Do...
# 4  ['Zoe Saldana, ', 'Laysla De Oliveira, ', 'Dav...
#
#                                          description     votes  \
# 0  Geralt of Rivia, a solitary monster hunter, st...  5,39,085
# 1  Ethan Hunt and his IMF team must track down a ...  1,06,759
# 2  The incredible true story of a former governme...    41,808
# 3  Fury and Talos try to stop the Skrulls who hav...    40,536
# 4  Joe attempts to balance her personal and profe...     3,203
#
#                     director
# 0                        NaN
# 1  ['Christopher McQuarrie']
# 2   ['Alejandro Monteverde']
# 3                        NaN
# 4                        NaN

# %%
print(df.columns)
# Out:
# Index(['movie', 'genre', 'runtime', 'certificate', 'rating', 'stars',
#        'description', 'votes', 'director'],
#       dtype='object')

# %%
print(df['rating'].isnull().sum())
# Out:
# 15510

# %%
print("Before dropping null ratings:", df.shape)
df = df.dropna(subset=['rating'])
print("After dropping null ratings:", df.shape)
# Out:
# Before dropping null ratings: (129891, 9)
# After dropping null ratings: (114381, 9)

# %%
print("Null genres before dropping:", df['genre'].isnull().sum())
df = df.dropna(subset=['genre'])
print("Shape after dropping null genres:", df.shape)
# Out:
# Null genres before dropping: 0
# Shape after dropping null genres: (114381, 9)

# %%
before = len(df)

df = df.drop_duplicates()

after = len(df)

print(f"Duplicates dropped: {before - after} ")
print("After removing duplicates:", df.shape)


print(df.head())
# Out:
# Duplicates dropped: 0
# After removing duplicates: (114381, 9)
#                                            movie  \
# 0                                    The Witcher
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                               Sound of Freedom
# 3                                Secret Invasion
# 4                           Special Ops: Lioness
#
#                                      genre  runtime certificate  rating  \
# 0     Action, Adventure, Drama               60 min           A     8.1
# 1  Action, Adventure, Thriller              163 min          UA     8.0
# 2     Action, Biography, Drama              131 min       PG-13     7.9
# 3     Action, Adventure, Drama               47 min      UA 16+     6.2
# 4      Action, Drama, Thriller                  NaN         NaN     7.5
#
#                                                stars  \
# 0  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 1  ['Tom Cruise, ', 'Hayley Atwell, ', 'Ving Rham...
# 2  ['Jim Caviezel, ', 'Mira Sorvino, ', 'Bill Cam...
# 3  ['Samuel L. Jackson, ', 'Emilia Clarke, ', 'Do...
# 4  ['Zoe Saldana, ', 'Laysla De Oliveira, ', 'Dav...
#
#                                          description     votes  \
# 0  Geralt of Rivia, a solitary monster hunter, st...  5,39,085
# 1  Ethan Hunt and his IMF team must track down a ...  1,06,759
# 2  The incredible true story of a former governme...    41,808
# 3  Fury and Talos try to stop the Skrulls who hav...    40,536
# 4  Joe attempts to balance her personal and profe...     3,203
#
#                     director
# 0                        NaN
# 1  ['Christopher McQuarrie']
# 2   ['Alejandro Monteverde']
# 3                        NaN
# 4                        NaN

# %%
df.head()
# Out:
#                                            movie  \
# 0                                    The Witcher
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                               Sound of Freedom
# 3                                Secret Invasion
# 4                           Special Ops: Lioness
#
#                                      genre  runtime certificate  rating  \
# 0     Action, Adventure, Drama               60 min           A     8.1
# 1  Action, Adventure, Thriller              163 min          UA     8.0
# 2     Action, Biography, Drama              131 min       PG-13     7.9
# 3     Action, Adventure, Drama               47 min      UA 16+     6.2
# 4      Action, Drama, Thriller                  NaN         NaN     7.5
#
#                                                stars  \
# 0  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 1  ['Tom Cruise, ', 'Hayley Atwell, ', 'Ving Rham...
# 2  ['Jim Caviezel, ', 'Mira Sorvino, ', 'Bill Cam...
# 3  ['Samuel L. Jackson, ', 'Emilia Clarke, ', 'Do...
# 4  ['Zoe Saldana, ', 'Laysla De Oliveira, ', 'Dav...
#
#                                          description     votes  \
# 0  Geralt of Rivia, a solitary monster hunter, st...  5,39,085
# 1  Ethan Hunt and his IMF team must track down a ...  1,06,759
# 2  The incredible true story of a former governme...    41,808
# 3  Fury and Talos try to stop the Skrulls who hav...    40,536
# 4  Joe attempts to balance her personal and profe...     3,203
#
#                     director
# 0                        NaN
# 1  ['Christopher McQuarrie']
# 2   ['Alejandro Monteverde']
# 3                        NaN
# 4                        NaN

# %%
df_exploded = df.copy()
df_exploded['genre'] = df_exploded['genre'].str.split(', ')
df_exploded = df_exploded.explode('genre')



df_exploded.head()
# Out:
#                                            movie              genre  runtime  \
# 0                                    The Witcher             Action   60 min
# 0                                    The Witcher          Adventure   60 min
# 0                                    The Witcher  Drama               60 min
# 1  Mission: Impossible - Dead Reckoning Part One             Action  163 min
# 1  Mission: Impossible - Dead Reckoning Part One          Adventure  163 min
#
#   certificate  rating                                              stars  \
# 0           A     8.1  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 0           A     8.1  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 0           A     8.1  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 1          UA     8.0  ['Tom Cruise, ', 'Hayley Atwell, ', 'Ving Rham...
# 1          UA     8.0  ['Tom Cruise, ', 'Hayley Atwell, ', 'Ving Rham...
#
#                                          description     votes  \
# 0  Geralt of Rivia, a solitary monster hunter, st...  5,39,085
# 0  Geralt of Rivia, a solitary monster hunter, st...  5,39,085
# 0  Geralt of Rivia, a solitary monster hunter, st...  5,39,085
# 1  Ethan Hunt and his IMF team must track down a ...  1,06,759
# 1  Ethan Hunt and his IMF team must track down a ...  1,06,759
#
#                     director
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 1  ['Christopher McQuarrie']
# 1  ['Christopher McQuarrie']

# %%
df_exploded['genre'] = df_exploded['genre'].str.strip()
df_exploded['movie'] = df_exploded['movie'].str.strip()

# %%
movies_by_genre = df_exploded.groupby('genre')['movie'].unique().reset_index()

movies_by_genre.head()
# Out:
#        genre                                              movie
# 0     Action  [The Witcher, Mission: Impossible - Dead Recko...
# 1      Adult                     [The Kama Sutra of Vatsyayana]
# 2  Adventure  [The Witcher, Mission: Impossible - Dead Recko...
# 3  Animation  [Invincible, Spider-Man: Across the Spider-Ver...
# 4  Biography  [Sound of Freedom, Spartacus: Blood and Sand, ...

# %%
avg_rating_by_genre = df_exploded.groupby('genre', as_index=False)['rating'].mean()

avg_rating_by_genre.head(80)
# Out:
#           genre    rating
# 0        Action  6.281501
# 1         Adult  4.500000
# 2     Adventure  6.412944
# 3     Animation  6.813222
# 4     Biography  6.968937
# 5        Comedy  6.362556
# 6         Crime  6.513369
# 7   Documentary  7.276078
# 8         Drama  6.566687
# 9        Family  6.433987
# 10      Fantasy  6.352960
# 11    Film-Noir  6.483040
# 12    Game-Show  6.558383
# 13      History  7.049478
# 14       Horror  5.385295
# 15        Music  6.866357
# 16      Musical  6.454928
# 17      Mystery  6.338088
# 18         News  7.028425
# 19   Reality-TV  6.582571
# 20      Romance  6.403032
# 21       Sci-Fi  5.733027
# 22        Short  6.960230
# 23        Sport  6.848459
# 24    Talk-Show  6.966786
# 25     Thriller  5.845827
# 26          War  6.661781
# 27      Western  5.999739

# %%
import numpy as np
avg_rating_by_genre['rating_group']= np.floor(avg_rating_by_genre['rating']).astype(int)

# %%
avg_rating_by_genre.head(100)
# Out:
#           genre    rating  rating_group
# 0        Action  6.281501             6
# 1         Adult  4.500000             4
# 2     Adventure  6.412944             6
# 3     Animation  6.813222             6
# 4     Biography  6.968937             6
# 5        Comedy  6.362556             6
# 6         Crime  6.513369             6
# 7   Documentary  7.276078             7
# 8         Drama  6.566687             6
# 9        Family  6.433987             6
# 10      Fantasy  6.352960             6
# 11    Film-Noir  6.483040             6
# 12    Game-Show  6.558383             6
# 13      History  7.049478             7
# 14       Horror  5.385295             5
# 15        Music  6.866357             6
# 16      Musical  6.454928             6
# 17      Mystery  6.338088             6
# 18         News  7.028425             7
# 19   Reality-TV  6.582571             6
# 20      Romance  6.403032             6
# 21       Sci-Fi  5.733027             5
# 22        Short  6.960230             6
# 23        Sport  6.848459             6
# 24    Talk-Show  6.966786             6
# 25     Thriller  5.845827             5
# 26          War  6.661781             6
# 27      Western  5.999739             5

# %%
import matplotlib.pyplot as plt
import seaborn as sns



plt.figure(figsize=(8,5))
sns.countplot(x='rating_group', data=avg_rating_by_genre.sort_values('rating_group'), palette='viridis')

plt.title('Number of Genres by Average Rating Group')
plt.xlabel('Average Rating Group (whole number)')
plt.ylabel('Count of Genres')
plt.tight_layout()
plt.show()

# %%
avg_rating_by_genre.set_index('genre')['rating_group']\
    .sort_values()\
    .plot(kind='barh', figsize=(8, len(avg_rating_by_genre) * 0.3))
plt.xlabel('Rating Group')
plt.title('Rating Group per Genre')
plt.tight_layout()
plt.show()

# %%
avg_rating_by_genre.to_csv('/home/yasmeen/Computer_Vision_program/avg_rating_by_genre.csv', index=False)

# %%
'''
 Which genres consistently recieve higher ratings?
 History, Documentary, and News consistently receive a rating of 7.

 '''

# %%
genre_summary = avg_rating_by_genre.merge(movies_by_genre, on='genre', how='left')


genre_summary.head(30)
# Out:
#           genre    rating  rating_group  \
# 0        Action  5.828057             5
# 1     Adventure  5.936002             5
# 2     Animation  6.393315             6
# 3     Biography  6.845727             6
# 4        Comedy  5.972972             5
# 5         Crime  6.205888             6
# 6   Documentary  7.133333             7
# 7         Drama  6.414548             6
# 8        Family  5.923259             5
# 9       Fantasy  5.748339             5
# 10    Film-Noir  7.186957             7
# 11      History  6.847420             6
# 12       Horror  5.262259             5
# 13        Music  6.487414             6
# 14      Musical  6.498605             6
# 15      Mystery  6.052822             6
# 16         News  6.950000             6
# 17   Reality-Tv  6.400000             6
# 18      Romance  6.230107             6
# 19       Sci-Fi  5.478109             5
# 20        Short  6.970732             6
# 21        Sport  6.166197             6
# 22     Thriller  5.754668             5
# 23          War  6.473859             6
# 24      Western  5.637202             5
#
#                                                 movie
# 0   [Mission: Impossible - Dead Reckoning Part One...
# 1   [Mission: Impossible - Dead Reckoning Part One...
# 2   [Miraculous - Le film, Resident Evil: Death Is...
# 3   [Sound of Freedom, Ford v Ferrari, American Sn...
# 4   [They Cloned Tyrone, The Out-Laws, Guardians o...
# 5   [The Out-Laws, The Dark Knight, John Wick: Cha...
# 6   [Jackass Forever, Jackass: The Movie, Jackass ...
# 7   [Sound of Freedom, The Dark Knight, Dunkirk, B...
# 8   [The Karate Kid, Harry Potter and the Order of...
# 9   [The Flash, Avatar: The Way of Water, Spider-M...
# 10  [To Have and Have Not, The Night of the Hunter...
# 11  [Dunkirk, Kingudamu, The Woman King, Black Haw...
# 12  [The Meg, The Flood, World War Z, From Dusk Ti...
# 13  [The Bodyguard, Dance Flick, Snipes, Bill & Te...
# 14  [Kaho Naa... Pyaar Hai, Prem Ratan Dhan Payo, ...
# 15  [They Cloned Tyrone, Blade Runner 2049, Watchm...
# 16  [An Inconvenient Truth, Before the Flood, Food...
# 17                               [Longest Third Date]
# 18  [Bawaal, Shotgun Wedding, A Knight's Tale, Nat...
# 19  [Transformers: Rise of the Beasts, Inception, ...
# 20  [The Hobbit: The Battle of the Five Armies - E...
# 21  [Warrior, Creed, Creed II, Rocky Balboa, Never...
# 22  [Mission: Impossible - Dead Reckoning Part One...
# 23  [Guy Ritchie's The Covenant, Sisu, 1917, Im We...
# 24  [Young Guns, The Old Way, The Harder They Fall...

# %%
genre_summary.to_csv('/home/yasmeen/Computer_Vision_program/IMDB_genre_ratings.csv', index=False)

# %%
print("Number of unique genres:", avg_rating_by_genre['genre'].nunique())
# Out:
# Number of unique genres: 25

# %%
avg_rating_by_genre.to_csv('/home/yasmeen/Computer_Vision_program/avg_rating_by_genre.csv', index=False)
